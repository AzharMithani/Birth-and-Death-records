# %% [markdown]
# # Data Visualization
#    Useful features of plotly can be used on the plots below
#    - Legend(top right) can be used to show or hide a particular trace/bar on the map
#    - Buttons (top left) can be used to select specific configuration of traces
#    - Hovering over the plot shows the values corresponding to x axis
#    - Range slider (below x axis) can be used choose the range to display on the plot

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import plotly.io as pio

import os
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
import plotly.tools as tls
init_notebook_mode(connected=True)

fileDir = os.path.dirname(os.path.realpath('__file__'))
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ### 1.Daily Birth and Death Trend
#    Plot shows male/female/total birth and death records on per day basis

# %%
day_wise = pd.read_csv('Insights/Day_wise_information.csv',header = 0)

day_wise['DOE']= pd.to_datetime((day_wise.Year*10000+day_wise.Month*100+day_wise.Day).apply(str),format='%Y%m%d')
male_birth_trace = go.Scatter(name = "Male births", x=day_wise.DOE, y=day_wise.male_births, line = dict(width = 1),opacity = 0.8)
male_death_trace = go.Scatter(name = "Male deaths",x=day_wise.DOE, y=day_wise.male_deaths, line = dict(width = 1),opacity = 0.8)
female_birth_trace = go.Scatter(name = "Femal births",x=day_wise.DOE, y=day_wise.female_births, line = dict(width = 1),opacity = 0.8)
female_death_trace = go.Scatter(name = "Femal deaths",x=day_wise.DOE, y=day_wise.female_deaths, line = dict(width = 1),opacity = 0.8)
total_birth_trace = go.Scatter(name = "Total births", x=day_wise.DOE, y=day_wise.total_births, line = dict(width = 1),opacity = 0.8)
total_death_trace = go.Scatter(name = "Total deaths", x=day_wise.DOE, y=day_wise.total_deaths, line = dict(width = 1),opacity = 0.8)


data = [male_birth_trace,female_birth_trace,total_birth_trace,male_death_trace,female_death_trace,total_death_trace]

updatemenus = list([dict(type="buttons",active=-1,buttons=list([\
                        dict(label = 'Birth',method = 'update',args = [{'visible': [True,True,True,False,False,False]},{'title': 'Births'}]),\
                        dict(label = 'Death',method = 'update',args = [{'visible': [False,False,False,True,True,True]},{'title': 'Deaths'}]),\
                        dict(label = 'Male',method = 'update',args = [{'visible': [True,False,False,True,False,False]},{'title': 'Male'}]),\
                        dict(label = 'Female',method = 'update',args = [{'visible': [False,True,False,False,True,False]},{'title': 'Female'}]),\
                        dict(label = 'All',method = 'update',args = [{'visible': [True,True,True,True,True,True]},{'title': 'All'}])
                        ]),direction = 'left',xanchor = 'left',y=1.1,yanchor = 'bottom',bgcolor='white',borderwidth = 1.5)])

layout = dict(title = "Daily Births and Deaths Trend",\
             xaxis = dict(title = "Date" , rangeslider = dict(visible = True)),\
             yaxis = dict(title = "Number of people" ),\
             #annotations=[dict(x=max_d, y=max_b,xref='x',yref='y',text='Maximum male births ',showarrow=True,arrowhead=3),\
             #             dict(x=min_d, y=min_b,xref='x',yref='y',text='Minimum male births ',showarrow=True,arrowhead=3)],\
              updatemenus=updatemenus)

fig = dict(data = data, layout = layout)

iplot(fig)
plot(fig, filename='plots/HTML files/1. Daily Births and Deaths Trend.html')
pio.write_image(fig,'plots/Static Images/1. Daily Births and Deaths Trend.jpeg')
# Out:
# <div id="81a31f28-7c2a-4ef2-a4c1-1dfb848d613e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
010-04-11 18:30:00", "2010-04-12 18:30:00", "2010-04-13 18:30:00", "2010-04-14 18:30:00", "2010-04-15 18:30:00", "2010-04-16 18:30:00", "2010-04-17 18:30:00", "2010-04-18 18:30:00", "2010-04-19 18:30:00", "2010-04-20 18:30:00", "2010-04-21 18:30:00", "2010-04-22 18:30:00", "2010-04-23 18:30:00", "2010-04-24 18:30:00", "2010-04-25 18:30:00", "2010-04-26 18:30:00", "2010-04-27 18:30:00", "2010-04-28 18:30:00", "2010-04-29 18:30:00", "2010-04-30 18:30:00", "2010-05-01 18:30:00", "2010-05-02 18:30:00", "2010-05-03 18:30:00", "2010-05-04 18:30:00", "2010-05-05 18:30:00", "2010-05-06 18:30:00", "2010-05-07 18:30:00", "2010-05-08 18:30:00", "2010-05-09 18:30:00", "2010-05-10 18:30:00", "2010-05-11 18:30:00", "2010-05-12 18:30:00", "2010-05-13 18:30:00", "2010-05-14 18:30:00", "2010-05-15 18:30:00", "2010-05-16 18:30:00", "2010-05-17 18:30:00", "2010-05-18 18:30:00", "2010-05-19 18:30:00", "2010-05-20 18:30:00", "2010-05-21 18:30:00", "2010-05-22 18:30:00", "2010-05-23 18:30:00", "2010-05-24 18:30:00", "2010-05-25 18:30:00", "2010-05-26 18:30:00", "2010-05-27 18:30:00", "2010-05-28 18:30:00", "2010-05-29 18:30:00", "2010-05-30 18:30:00", "2010-05-31 18:30:00", "2010-06-01 18:30:00", "2010-06-02 18:30:00", "2010-06-03 18:30:00", "2010-06-04 18:30:00", "2010-06-05 18:30:00 ...

# %% [markdown]
# ### 2. Monthly Birth and Death Trend
#    Plot shows male/female/total birth and death records on per month basis

# %%
month_wise = pd.read_csv('Insights/Month_wise_information.csv',header = 0)

month_wise['DOE']= pd.to_datetime((month_wise.Year*100+month_wise.Month).apply(str),format='%Y%m')
male_birth_trace = go.Scatter(name = "Male births", x=month_wise.DOE, y=month_wise.male_births, line = dict(width = 1),opacity = 0.8)
male_death_trace = go.Scatter(name = "Male deaths",x=month_wise.DOE, y=month_wise.male_deaths, line = dict(width = 1),opacity = 0.8)
female_birth_trace = go.Scatter(name = "Femal births",x=month_wise.DOE, y=month_wise.female_births, line = dict(width = 1),opacity = 0.8)
female_death_trace = go.Scatter(name = "Femal deaths",x=month_wise.DOE, y=month_wise.female_deaths, line = dict(width = 1),opacity = 0.8)
total_birth_trace = go.Scatter(name = "Total births", x=month_wise.DOE, y=month_wise.total_births, line = dict(width = 1),opacity = 0.8)
total_death_trace = go.Scatter(name = "Total deaths", x=month_wise.DOE, y=month_wise.total_deaths, line = dict(width = 1),opacity = 0.8)


data = [male_birth_trace,female_birth_trace,total_birth_trace,male_death_trace,female_death_trace,total_death_trace]

updatemenus = list([dict(type="buttons",active=-1,buttons=list([\
                        dict(label = 'Birth',method = 'update',args = [{'visible': [True,True,True,False,False,False]},{'title': 'Births'}]),\
                        dict(label = 'Death',method = 'update',args = [{'visible': [False,False,False,True,True,True]},{'title': 'Deaths'}]),\
female_death_trace = go.Bar(name = "Femal deaths",x=year_wise.DOE, y=year_wise.female_deaths)
total_birth_trace = go.Bar(name = "Total births", x=year_wise.DOE, y=year_wise.male_births + year_wise.female_births)
total_death_trace = go.Bar(name = "Total deaths", x=year_wise.DOE, y=year_wise.male_deaths+year_wise.female_deaths)


data = [male_birth_trace,female_birth_trace,total_birth_trace,male_death_trace,female_death_trace,total_death_trace]
updatemenus = list([dict(type="buttons",active=-1,buttons=list([\
                        dict(label = 'Birth',method = 'update',args = [{'visible': [True,True,True,False,False,False]},{'title': 'Births'}]),\
                        dict(label = 'Death',method = 'update',args = [{'visible': [False,False,False,True,True,True]},{'title': 'Deaths'}]),\
                        dict(label = 'Male',method = 'update',args = [{'visible': [True,False,False,True,False,False]},{'title': 'Male'}]),\
                        dict(label = 'Female',method = 'update',args = [{'visible': [False,True,False,False,True,False]},{'title': 'Female'}]),\
                        dict(label = 'All',method = 'update',args = [{'visible': [True,True,True,True,True,True]},{'title': 'All'}])
                        ]),direction = 'left',xanchor = 'left',y=1.1,yanchor = 'bottom',bgcolor='white',borderwidth = 1.5)])


layout = dict(title = "Yearly Births and Deaths",\
             xaxis = dict(title = "Year"),\
             yaxis = dict(title = "Number of people"),\
             updatemenus = updatemenus)

fig = dict(data = data, layout = layout)

iplot(fig)
plot(fig, filename='plots/HTML files/3. Yearly Births and Deaths Trend.html')
pio.write_image(fig,'plots/Static Images/3. Yearly Births and Deaths Trend.jpeg')
# Out:
# <div id="3f792e4c-fb8a-49bb-952e-a4bf28f07eb3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3f792e4c-fb8a-49bb-952e-a4bf28f07eb3", [{"name": "Male births", "x": ["2010-01-19 18:30:00", "2011-01-19 18:30:00", "2012-01-19 18:30:00", "2013-01-19 18:30:00", "2014-01-19 18:30:00", "2015-01-19 18:30:00", "2016-01-19 18:30:00", "2017-01-19 18:30:00", "2018-01-19 18:30:00"], "y": [27131, 28228, 29523, 30179, 28253, 28549, 28775, 29002, 9166], "type": "bar", "uid": "e4a18142-6211-4156-b148-bc60e8a20e04"}, {"name": "Femal births", "x": ["2010-01-19 18:30:00", "2011-01-19 18:30:00", "2012-01-19 18:30:00", "2013-01-19 18:30:00", "2014-01-19 18:30:00", "2015-01-19 18:30:00", "2016-01-19 18:30:00", "2017-01-19 18:30:00", "2018-01-19 18:30:00"], "y": [23965, 25094, 27612, 28222, 26511, 26436, 26854, 26981, 8490], "type": "bar", "uid": "13bcdbae-7fb0-4bb4-ab41-2b23e5378836"}, {"name": "Total births", "x": ["2010-01-19 18:30:00", "2011-01-19 18:30:00", "2012-01-19 18:30:00", "2013-01-19 18:30:00", "2014-01-19 18:30:00", "2015-01-19 18:30:00", "2016-01-19 18:30:00", "2017-01-19 18:30:00", "2018-01-19 18:30:00"], "y": [51096, 53322, 57135, 58401, 54764, 54985, 55629, 55983, 17656], "type": "bar", "uid": "fcada4ac-32a7-4b02-857a-d61180a7a91a"}, {"name": "Male deaths", "x": ["2010-01-19 18:30:00", "2011-01-19 18:30:00", "2012-01-19 18:30:00", "2013-01-19 18:30:00", "2014-01-19 18:30:00", "2015-01-19 18:30:00", "2016-01-19 18:30:00", "2017-01-19 18:30:00", "2018-01-19 18:30:00"], "y": [15919, 16013, 15990, 16135, 16763, 16830, 18622, 16718, 6026], "type": "bar", "uid": "0066fc9c-de17-487b-9f91-f90880627af2"}, {"name": "Femal deaths", "x": ["2010-01-19 18:30:00", "2011-01-19 18:30:00", "2012-01-19 18:30:00", "2013-01-19 18:30:00", "2014-01-19 18:30:00", "2015-01-19 18:30:00", "2016-01-19 18:30:00", "2017-01-19 18:30:00", "2018-01-19 18:30:00"], "y": [10869, 11179, 11332, 11338, 11481, 11739, 12752, 11941, 4307], "type": "bar", "uid": "a0a3bf1c-97bd-44b3-9812-a6a0a8f3e552"}, {"name": "Total deaths", "x": ["2010-01-19 18:30:00", "2011-01-19 18:30:00", "2012-01-19 18:30:00", "2013-01-19 18:30:00", "2014-01-19 18:30:00", "2015-01-19 18:30:00", "2016-01-19 18:30:00", "2017-01-19 18:30:00", "2018-01-19 18:30:00"], "y": [26788, 27192, 27322, 27473, 28244, 28569, 31374, 28659, 10333], "type": "bar", "uid": "2877dded-ebb0-4271-a2d5-6a864b7e791a"}], {"title": {"text": "Yearly Births and Deaths"}, "updatemenus": [{"active": -1, "bgcolor": "white", "borderwidth": 1.5, "buttons": [{"args": [{"visible": [true, true, true, false, false, false]}, {"title": "Births"}], "label": "Birth", "method": "update"}, {"args": [{"visible": [false, false, false, true, true, true]}, {"title": "Deaths"}], "label": "Death", "method": "update"}, {"args": [{"visible": [true, false, false, true, false, false]}, {"title": "Male"}], "label": "Male", "method": "update"}, {"args": [{"visible": [false, true, false, false, true, false]}, {"title": "Female"}], "label": "Female", "method": "update"}, {"args": [{"visible": [true, true, true, true, true, true]}, {"title": "All"}], "label": "All", "method": "update"}], "direction": "left", "type": "buttons", "xanchor": "left", "y": 1.1, "yanchor": "bottom"}], "xaxis": {"title": {"text": "Year"}}, "yaxis": {"title": {"text": "Number of people"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("3f792e4c-fb8a-49bb-952e-a4bf28f07eb3"));});</script>

# %%
combined_filename = os.path.join(fileDir, 'cleaned_datasets\\combined_cleaned_birth_and_death_2010-2011.csv')
combined = pd.read_csv(combined_filename,header = 0)

# [[[birth_male, birth_female, birth_total, death_male, death_female, death_total] for months ] for years ]
analysis = [[[] for _ in range(12)] for __ in range(9)]

for i in range(9):
    for j in range(12):
        a = len(combined[(combined['Year'] == 2010+i) & (combined['Month'] == j+1) & (combined['Type'] == 0) & (combined['Gender'] == 0)])
        analysis[i][j].append(a)
        b = len(combined[(combined['Year'] == 2010+i) & (combined['Month'] == j+1) & (combined['Type'] == 0) & (combined['Gender'] == 1)])
        analysis[i][j].append(b)
        analysis[i][j].append(a+b)
        a = len(combined[(combined['Year'] == 2010+i) & (combined['Month'] == j+1) & (combined['Type'] == 1) & (combined['Gender'] == 0)])
        analysis[i][j].append(a)
        b = len(combined[(combined['Year'] == 2010+i) & (combined['Month'] == j+1) & (combined['Type'] == 1) & (combined['Gender'] == 1)])
        analysis[i][j].append(b)
        analysis[i][j].append(a+b)

for i in range(9):
    analysis[i] = [list(_) for _ in zip(*analysis[i])]

# %% [markdown]
# ### 4. Trend for Male Births
#    Plot shows trend for male births

# %%
x = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
trace = []
data = []
for i in range(8):
    trace.append(go.Scatter(name = str(2010+i), x=x, y=analysis[i][0], line = dict(width = 1),opacity = 0.8))
    data.append(trace[i])

trace.append(go.Scatter(name='2018',x =  ['Jan','Feb','Mar','Apr'],y=analysis[8][0][:4]))    
data.append(trace[-1])

layout = dict(title = "Male Births Trend",\
             xaxis = dict(title = "Month" , rangeslider = dict(visible = True)),\
             yaxis = dict(title = "Number of people" ))

fig = dict(data = data, layout = layout)
iplot(fig)
plot(fig, filename='plots/HTML files/4. Trend for Male Births.html')
pio.write_image(fig,'plots/Static Images/4. Trend for Male Births.jpeg')
# Out:
# <div id="e5d33a31-e276-4340-a1a1-8c661401be1f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e5d33a31-e276-4340-a1a1-8c661401be1f", [{"line": {"width": 1}, "name": "2010", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2114, 1925, 2402, 2244, 2102, 1971, 2134, 2312, 2507, 2718, 2423, 2279], "type": "scatter", "uid": "002b0657-8d55-4d9f-b15f-4ad2666531f2"}, {"line": {"width": 1}, "name": "2011", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2109, 1937, 2543, 2250, 2213, 2127, 2209, 2301, 2557, 2814, 2675, 2493], "type": "scatter", "uid": "23760cd9-e212-43d6-9008-1aa38aa41223"}, {"line": {"width": 1}, "name": "2012", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2322, 2335, 2620, 2391, 2449, 2189, 2300, 2566, 2620, 2667, 2571, 2493], "type": "scatter", "uid": "6478c790-cbf4-46fa-a27a-7dbc077b5870"}, {"line": {"width": 1}, "name": "2013", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2499, 2390, 2758, 2413, 2518, 2238, 2308, 2518, 2650, 2910, 2547, 2430], "type": "scatter", "uid": "d5380ba6-2c4e-4d41-8c81-51f21cae76a5"}, {"line": {"width": 1}, "name": "2014", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2367, 2115, 2525, 2282, 2248, 2164, 2266, 2467, 2449, 2632, 2453, 2285], "type": "scatter", "uid": "25cf947c-8d05-4d26-9d50-62e13dd6ce0b"}, {"line": {"width": 1}, "name": "2015", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2314, 2153, 2436, 2364, 2156, 2138, 2236, 2467, 2559, 2783, 2505, 2438], "type": "scatter", "uid": "2e371aa9-f9c3-49ad-8542-9db29f1adbc3"}, {"line": {"width": 1}, "name": "2016", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2349, 2249, 2507, 2470, 2318, 2184, 2241, 2426, 2431, 2717, 2484, 2399], "type": "scatter", "uid": "a8eb9e9f-bd29-4c3e-9306-66fd68701065"}, {"line": {"width": 1}, "name": "2017", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2286, 2189, 2449, 2251, 2297, 2118, 2360, 2466, 2700, 2753, 2668, 2465], "type": "scatter", "uid": "2b633db5-8ef3-4468-97aa-f129b3d1f197"}, {"name": "2018", "x": ["Jan", "Feb", "Mar", "Apr"], "y": [2331, 2163, 2496, 2176], "type": "scatter", "uid": "1503311d-46b6-44b1-b24b-867f0fd7b95f"}], {"title": {"text": "Male Births Trend"}, "xaxis": {"rangeslider": {"visible": true}, "title": {"text": "Month"}}, "yaxis": {"title": {"text": "Number of people"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("e5d33a31-e276-4340-a1a1-8c661401be1f"));});</script>

# %% [markdown]
# ### 5. Trend for Female Births
#    Plot shows trend for female births

# %%
x = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
trace = []
data = []
for i in range(8):
    trace.append(go.Scatter(name = str(2010+i), x=x, y=analysis[i][1], line = dict(width = 1),opacity = 0.8))
    data.append(trace[i])

trace.append(go.Scatter(name='2018',x =  ['Jan','Feb','Mar','Apr'],y=analysis[8][1][:4]))    
data.append(trace[-1])

layout = dict(title = "Feale Births Trend",\
             xaxis = dict(title = "Month" , rangeslider = dict(visible = True)),\
             yaxis = dict(title = "Number of people" ))

fig = dict(data = data, layout = layout)

iplot(fig)
plot(fig, filename='plots/HTML files/5. Trend for Female Births.html')
pio.write_image(fig,'plots/Static Images/5. Trend for Female Births.jpeg')
# Out:
# <div id="5b5cee57-e93f-4bc5-991a-cc2740a6d40a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5b5cee57-e93f-4bc5-991a-cc2740a6d40a", [{"line": {"width": 1}, "name": "2010", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1882, 1737, 2155, 1809, 1837, 1717, 1891, 2064, 2235, 2375, 2163, 2100], "type": "scatter", "uid": "65cd91dd-f8cd-43a2-a110-8a38f0d2497b"}, {"line": {"width": 1}, "name": "2011", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1829, 1736, 2140, 2002, 1956, 1856, 1939, 2063, 2235, 2446, 2541, 2351], "type": "scatter", "uid": "f8e7b58a-8017-4a67-b8c5-ebdc47e74669"}, {"line": {"width": 1}, "name": "2012", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2242, 2214, 2363, 2276, 2265, 2079, 2184, 2354, 2405, 2490, 2408, 2332], "type": "scatter", "uid": "d7746e83-7351-41e0-aad3-1ee7b32c9456"}, {"line": {"width": 1}, "name": "2013", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2229, 2143, 2555, 2414, 2304, 2035, 2208, 2425, 2374, 2730, 2459, 2346], "type": "scatter", "uid": "680bb9c6-0b95-4ed0-8e16-5fcccfd10e3d"}, {"line": {"width": 1}, "name": "2014", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2218, 2026, 2331, 2243, 2215, 1913, 2175, 2194, 2266, 2461, 2278, 2191], "type": "scatter", "uid": "3c1e2e52-9ace-47b0-b8e4-2ba4374c90da"}, {"line": {"width": 1}, "name": "2015", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2122, 1858, 2251, 2104, 2129, 1898, 2106, 2347, 2517, 2548, 2333, 2223], "type": "scatter", "uid": "90df1bae-9e3c-4420-8087-970f89adc60b"}, {"line": {"width": 1}, "name": "2016", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2110, 2081, 2322, 2326, 2199, 2070, 2000, 2322, 2318, 2596, 2360, 2150], "type": "scatter", "uid": "aefeb30d-2645-4a31-8fa6-763f70df5574"}, {"line": {"width": 1}, "name": "2017", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2107, 1877, 2195, 2096, 2129, 2018, 2109, 2481, 2479, 2655, 2489, 2346], "type": "scatter", "uid": "7ff2c266-5df2-4632-b581-8b5eab89de70"}, {"name": "2018", "x": ["Jan", "Feb", "Mar", "Apr"], "y": [2178, 1979, 2317, 2016], "type": "scatter", "uid": "7dcbc630-c986-4026-90a1-56bb5a70c164"}], {"title": {"text": "Feale Births Trend"}, "xaxis": {"rangeslider": {"visible": true}, "title": {"text": "Month"}}, "yaxis": {"title": {"text": "Number of people"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("5b5cee57-e93f-4bc5-991a-cc2740a6d40a"));});</script>

# %% [markdown]
# ### 6. Trend for Total Births
#    Plot shows trend for total births

# %%
x = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
trace = []
data = []
for i in range(8):
    trace.append(go.Scatter(name = str(2010+i), x=x, y=analysis[i][2], line = dict(width = 1),opacity = 0.8))
    data.append(trace[i])

trace.append(go.Scatter(name='2018',x =  ['Jan','Feb','Mar','Apr'],y=analysis[8][2][:4]))    
data.append(trace[-1])

layout = dict(title = "Total Births Trend",\
             xaxis = dict(title = "Month" , rangeslider = dict(visible = True)),\
             yaxis = dict(title = "Number of people" ))

fig = dict(data = data, layout = layout)

iplot(fig)
plot(fig, filename='plots/HTML files/6. Trend for Total Births.html')
pio.write_image(fig,'plots/Static Images/6. Trend for Total Births.jpeg')
# Out:
# <div id="cffb7373-606b-4849-b7cd-a001034b8ed9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cffb7373-606b-4849-b7cd-a001034b8ed9", [{"line": {"width": 1}, "name": "2010", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [3996, 3662, 4557, 4053, 3939, 3688, 4025, 4376, 4742, 5093, 4586, 4379], "type": "scatter", "uid": "5c9f8a0b-756c-4ae1-80c9-caeb6d21b846"}, {"line": {"width": 1}, "name": "2011", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [3938, 3673, 4683, 4252, 4169, 3983, 4148, 4364, 4792, 5260, 5216, 4844], "type": "scatter", "uid": "2606f801-f792-4ba2-9934-4ebb293a6439"}, {"line": {"width": 1}, "name": "2012", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [4564, 4549, 4983, 4667, 4714, 4268, 4484, 4920, 5025, 5157, 4979, 4825], "type": "scatter", "uid": "2ffb216f-69d9-42a7-8cdf-8f03c257835f"}, {"line": {"width": 1}, "name": "2013", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [4728, 4533, 5313, 4827, 4822, 4273, 4516, 4943, 5024, 5640, 5006, 4776], "type": "scatter", "uid": "0a4c0727-c91d-4e5f-b4f0-bb75a81ee4c9"}, {"line": {"width": 1}, "name": "2014", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [4585, 4141, 4856, 4525, 4463, 4077, 4441, 4661, 4715, 5093, 4731, 4476], "type": "scatter", "uid": "3ca17e7c-2c9e-40c1-9dfb-98df5c260a3d"}, {"line": {"width": 1}, "name": "2015", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [4436, 4011, 4687, 4468, 4285, 4036, 4342, 4814, 5076, 5331, 4838, 4661], "type": "scatter", "uid": "ed3164e8-c566-499f-899a-e29f9f360a9b"}, {"line": {"width": 1}, "name": "2016", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [4459, 4330, 4829, 4796, 4517, 4254, 4241, 4748, 4749, 5313, 4844, 4549], "type": "scatter", "uid": "a8c24228-7938-47df-bb41-fc2e941169ae"}, {"line": {"width": 1}, "name": "2017", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [4393, 4066, 4644, 4347, 4426, 4136, 4469, 4947, 5179, 5408, 5157, 4811], "type": "scatter", "uid": "fad36c86-7ae2-4205-bcde-8ed10cfe33c8"}, {"name": "2018", "x": ["Jan", "Feb", "Mar", "Apr"], "y": [4509, 4142, 4813, 4192], "type": "scatter", "uid": "bfd20d7b-f292-4309-8285-c160242f3ead"}], {"title": {"text": "Total Births Trend"}, "xaxis": {"rangeslider": {"visible": true}, "title": {"text": "Month"}}, "yaxis": {"title": {"text": "Number of people"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("cffb7373-606b-4849-b7cd-a001034b8ed9"));});</script>

# %% [markdown]
# ### 7. Trend for Male Deaths
#    Plot shows trend for male deaths

# %%
x = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
trace = []
data = []
for i in range(8):
    trace.append(go.Scatter(name = str(2010+i), x=x, y=analysis[i][3], line = dict(width = 1),opacity = 0.8))
    data.append(trace[i])

trace.append(go.Scatter(name='2018',x =  ['Jan','Feb','Mar','Apr'],y=analysis[8][3][:4]))    
data.append(trace[-1])

layout = dict(title = "Male Death Trend",\
             xaxis = dict(title = "Month" , rangeslider = dict(visible = True)),\
             yaxis = dict(title = "Number of people" ))

fig = dict(data = data, layout = layout)
iplot(fig)
plot(fig, filename='plots/HTML files/7. Trend for Male Deaths.html')
pio.write_image(fig,'plots/Static Images/7. Trend for Male Deaths.jpeg')
# Out:
# <div id="7e8d79dc-e173-4fcb-a490-0b90974c921e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7e8d79dc-e173-4fcb-a490-0b90974c921e", [{"line": {"width": 1}, "name": "2010", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1345, 1172, 1143, 1274, 1215, 1227, 1376, 1510, 1461, 1313, 1285, 1598], "type": "scatter", "uid": "ec1c8e2b-45f9-4ab9-8391-666cdbf35653"}, {"line": {"width": 1}, "name": "2011", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1564, 1198, 1302, 1201, 1174, 1197, 1410, 1438, 1420, 1347, 1349, 1413], "type": "scatter", "uid": "6f7772fe-e9c4-4c7d-a3c3-d64b91cf669b"}, {"line": {"width": 1}, "name": "2012", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1549, 1299, 1342, 1327, 1229, 1185, 1230, 1445, 1417, 1327, 1270, 1370], "type": "scatter", "uid": "9a3a6d4a-24ad-4f29-b45e-6faaf0b795a4"}, {"line": {"width": 1}, "name": "2013", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1462, 1265, 1398, 1311, 1215, 1139, 1392, 1483, 1289, 1353, 1316, 1512], "type": "scatter", "uid": "eedfd135-e53f-42f2-b758-0241bfdc9430"}, {"line": {"width": 1}, "name": "2014", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1464, 1265, 1399, 1295, 1321, 1258, 1340, 1539, 1538, 1400, 1390, 1554], "type": "scatter", "uid": "952e5f5d-cf39-4503-9bb7-ce051767fd5f"}, {"line": {"width": 1}, "name": "2015", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1599, 1330, 1466, 1291, 1275, 1171, 1285, 1440, 1453, 1469, 1515, 1536], "type": "scatter", "uid": "8ff61d6f-d8dc-495a-a6ba-7abcf76bf3df"}, {"line": {"width": 1}, "name": "2016", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1639, 1428, 1437, 1342, 1393, 1270, 1695, 1869, 1732, 1660, 1552, 1605], "type": "scatter", "uid": "2a579c74-2d61-4c82-b3ed-659dde087d4a"}, {"line": {"width": 1}, "name": "2017", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1630, 1317, 1488, 1415, 1311, 1309, 678, 1176, 1560, 1634, 1585, 1615], "type": "scatter", "uid": "ece48b5d-c134-492b-a926-fc2fa37efa31"}, {"name": "2018", "x": ["Jan", "Feb", "Mar", "Apr"], "y": [1696, 1485, 1510, 1335], "type": "scatter", "uid": "fb03923b-17b0-493e-a5f9-9a54651b0339"}], {"title": {"text": "Male Death Trend"}, "xaxis": {"rangeslider": {"visible": true}, "title": {"text": "Month"}}, "yaxis": {"title": {"text": "Number of people"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("7e8d79dc-e173-4fcb-a490-0b90974c921e"));});</script>

# %% [markdown]
# ### 8. Trend for Female Deaths
#    Plot shows trend for female deaths

# %%
x = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
trace = []
data = []
for i in range(8):
    trace.append(go.Scatter(name = str(2010+i), x=x, y=analysis[i][4], line = dict(width = 1),opacity = 0.8))
    data.append(trace[i])

trace.append(go.Scatter(name='2018',x =  ['Jan','Feb','Mar','Apr'],y=analysis[8][4][:4]))    
data.append(trace[-1])

layout = dict(title = "Feale Death Trend",\
             xaxis = dict(title = "Month" , rangeslider = dict(visible = True)),\
             yaxis = dict(title = "Number of people" ))

fig = dict(data = data, layout = layout)
iplot(fig)
plot(fig, filename='plots/HTML files/8. Trend for Female Deaths.html')
pio.write_image(fig,'plots/Static Images/8. Trend for Female Deaths.jpeg')
# Out:
# <div id="f9413cc1-7065-404a-a26b-1bd38c3ba3d4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f9413cc1-7065-404a-a26b-1bd38c3ba3d4", [{"line": {"width": 1}, "name": "2010", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [934, 812, 879, 896, 811, 781, 921, 1006, 986, 899, 903, 1041], "type": "scatter", "uid": "aebd883f-170b-4cc9-b148-2700047ceb03"}, {"line": {"width": 1}, "name": "2011", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1156, 818, 882, 871, 858, 880, 1022, 986, 939, 904, 890, 973], "type": "scatter", "uid": "52fac9db-2d16-412b-bca6-e0aed025919f"}, {"line": {"width": 1}, "name": "2012", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1081, 967, 1020, 879, 881, 806, 864, 958, 988, 970, 958, 960], "type": "scatter", "uid": "58411e0f-5c41-4f64-9230-21eb8ee35e11"}, {"line": {"width": 1}, "name": "2013", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [999, 858, 1026, 980, 881, 802, 923, 992, 962, 939, 908, 1068], "type": "scatter", "uid": "a42e9a93-c796-43b9-82d4-45f3f62fd5e4"}, {"line": {"width": 1}, "name": "2014", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [967, 905, 920, 919, 901, 820, 945, 992, 1106, 1009, 915, 1082], "type": "scatter", "uid": "cfbb45b2-0dc7-41e6-bf89-34db9a099da9"}, {"line": {"width": 1}, "name": "2015", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1125, 954, 1004, 911, 941, 869, 903, 940, 1003, 1039, 1034, 1016], "type": "scatter", "uid": "fc744739-0b41-498e-a392-bd02438b26b5"}, {"line": {"width": 1}, "name": "2016", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1143, 1028, 933, 950, 968, 808, 1129, 1348, 1119, 1171, 1076, 1079], "type": "scatter", "uid": "f55dbc99-b45d-4118-bcae-6c94c37bbfea"}, {"line": {"width": 1}, "name": "2017", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1169, 904, 1086, 1014, 1015, 861, 499, 914, 1068, 1188, 1089, 1134], "type": "scatter", "uid": "3daaca8b-f980-4406-aa81-bfd6b4dfd80b"}, {"name": "2018", "x": ["Jan", "Feb", "Mar", "Apr"], "y": [1189, 1099, 1073, 946], "type": "scatter", "uid": "5ca15e72-9ac7-42c0-9899-a23cc958a06e"}], {"title": {"text": "Feale Death Trend"}, "xaxis": {"rangeslider": {"visible": true}, "title": {"text": "Month"}}, "yaxis": {"title": {"text": "Number of people"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("f9413cc1-7065-404a-a26b-1bd38c3ba3d4"));});</script>

# %% [markdown]
# ### 9. Trend for Total Deaths
#    Plot shows trend for total deaths

# %%
x = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
trace = []
data = []
for i in range(8):
    trace.append(go.Scatter(name = str(2010+i), x=x, y=analysis[i][5], line = dict(width = 1),opacity = 0.8))
    data.append(trace[i])

trace.append(go.Scatter(name='2018',x =  ['Jan','Feb','Mar','Apr'],y=analysis[8][5][:4]))    
data.append(trace[-1])

layout = dict(title = "Total Death Trend",\
             xaxis = dict(title = "Month" , rangeslider = dict(visible = True)),\
             yaxis = dict(title = "Number of people" ))

fig = dict(data = data, layout = layout)
iplot(fig)
plot(fig, filename='plots/HTML files/9. Trend for Total Deaths.html')
pio.write_image(fig,'plots/Static Images/9. Trend for Total Deaths.jpeg')
# Out:
# <div id="c989c20c-780b-4d2e-a96f-115fd8ff39bf" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c989c20c-780b-4d2e-a96f-115fd8ff39bf", [{"line": {"width": 1}, "name": "2010", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2279, 1984, 2022, 2170, 2026, 2008, 2297, 2516, 2447, 2212, 2188, 2639], "type": "scatter", "uid": "4b980d96-5a5d-461f-800e-a91a6282828f"}, {"line": {"width": 1}, "name": "2011", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2720, 2016, 2184, 2072, 2032, 2077, 2432, 2424, 2359, 2251, 2239, 2386], "type": "scatter", "uid": "0bf99334-f1d6-44ee-aa43-432ec4b9b109"}, {"line": {"width": 1}, "name": "2012", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2630, 2266, 2362, 2206, 2110, 1991, 2094, 2403, 2405, 2297, 2228, 2330], "type": "scatter", "uid": "a4371c4f-d0f9-4ce8-ac9e-366738511a25"}, {"line": {"width": 1}, "name": "2013", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2461, 2123, 2424, 2291, 2096, 1941, 2315, 2475, 2251, 2292, 2224, 2580], "type": "scatter", "uid": "d5194700-55b0-4a7d-b821-0b9705938dea"}, {"line": {"width": 1}, "name": "2014", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2431, 2170, 2319, 2214, 2222, 2078, 2285, 2531, 2644, 2409, 2305, 2636], "type": "scatter", "uid": "b8a4c3c3-c1ff-4e34-a291-d4ff6b67677f"}, {"line": {"width": 1}, "name": "2015", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2724, 2284, 2470, 2202, 2216, 2040, 2188, 2380, 2456, 2508, 2549, 2552], "type": "scatter", "uid": "79afd3fc-5917-43de-8cf5-eb9fd48b8eeb"}, {"line": {"width": 1}, "name": "2016", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2782, 2456, 2370, 2292, 2361, 2078, 2824, 3217, 2851, 2831, 2628, 2684], "type": "scatter", "uid": "b0eb617f-8157-48c7-85d3-673ca0bf319a"}, {"line": {"width": 1}, "name": "2017", "opacity": 0.8, "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2799, 2221, 2574, 2429, 2326, 2170, 1177, 2090, 2628, 2822, 2674, 2749], "type": "scatter", "uid": "dce16d9c-597c-48e7-8d1d-ced52fd2ddec"}, {"name": "2018", "x": ["Jan", "Feb", "Mar", "Apr"], "y": [2885, 2584, 2583, 2281], "type": "scatter", "uid": "989b67c5-56e4-49e1-a6d8-c16295861c1a"}], {"title": {"text": "Total Death Trend"}, "xaxis": {"rangeslider": {"visible": true}, "title": {"text": "Month"}}, "yaxis": {"title": {"text": "Number of people"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("c989c20c-780b-4d2e-a96f-115fd8ff39bf"));});</script>

# %% [markdown]
# ### 10. Yearly population growth
#    Plot shows male/female/total yearly population growth

# %%
year_wise = pd.read_csv('Insights/Year_wise_information.csv',header = 0)

male_trace = go.Bar(x=year_wise.Year,y=year_wise.male_population_growth,name="Male")
female_trace = go.Bar(x=year_wise.Year,y=year_wise.female_population_growth,name="Female")
total_trace = go.Bar(x=year_wise.Year,y=year_wise.female_population_growth+year_wise.male_population_growth,name="Total")

data = [male_trace,female_trace,total_trace]

layout = dict(title = "Yearly Population growth",\
             xaxis = dict(title = "Year"),\
             yaxis = dict(title = "Population Growth" ))

fig = dict(data = data, layout = layout)

iplot(fig)
plot(fig, filename='plots/HTML files/10. Yearly Population Growth.html')
pio.write_image(fig,'plots/Static Images/10. Yearly Population Growth.jpeg')
# Out:
# <div id="4958872a-5f7d-4f7a-9ba9-232bb35526ed" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4958872a-5f7d-4f7a-9ba9-232bb35526ed", [{"name": "Male", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [11212, 12215, 13533, 14044, 11490, 11719, 10153, 12284, 3140], "type": "bar", "uid": "186dfb36-627a-4e87-ac6e-212638f4af26"}, {"name": "Female", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [13096, 13915, 16280, 16884, 15030, 14697, 14102, 15040, 4183], "type": "bar", "uid": "770ea244-8c1c-475b-9c40-2f6b059d5764"}, {"name": "Total", "x": [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018], "y": [24308, 26130, 29813, 30928, 26520, 26416, 24255, 27324, 7323], "type": "bar", "uid": "2e64a412-6b8d-452a-a4e5-b8fa1ce52b6e"}], {"title": {"text": "Yearly Population growth"}, "xaxis": {"title": {"text": "Year"}}, "yaxis": {"title": {"text": "Population Growth"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("4958872a-5f7d-4f7a-9ba9-232bb35526ed"));});</script>

# %% [markdown]
# ### 11. Yearly Increase/Decrease in Birth Rate
#    Plot shows male/female/total Yearly change in Birth Rate
#    (As we are not considering data for 2009, this plot has the birth rate statictics from year 2011)

# %%
a = year_wise.male_population_growth.values[:8]
b = year_wise.female_population_growth[:8]
c = year_wise.male_population_growth[:8] + year_wise.female_population_growth[:8]
growth_percent = []

for i in range(1,8):
    growth_percent.append(round((a[i] - a[i-1]) / a[i-1] * 100,2))
for i in range(1,8):
    growth_percent.append(round((b[i] - b[i-1]) / b[i-1] * 100,2))
for i in range(1,8):
    growth_percent.append(round((c[i] - c[i-1]) / c[i-1] * 100,2))
x = ['2011','2012','2013','2014','2015','2016','2017']
male_trace = go.Bar(x=x,y=growth_percent[:7],name="Male")
female_trace = go.Bar(x=x,y=growth_percent[7:14],name="Female")
total_trace = go.Bar(x=x,y=growth_percent[14:21],name="Total")

data = [male_trace,female_trace,total_trace]

layout = dict(title = "Yearly Increase/Decrease in Birth Rate",\
             xaxis = dict(title = "Year"),\
             yaxis = dict(title = "Population Growth" ))

fig = dict(data = data, layout = layout)

iplot(fig)
plot(fig, filename='plots/HTML files/11. Yearly Increase or Decrease in Birth Rate.html')
pio.write_image(fig,'plots/Static Images/11. Yearly Increase or Decrease in Birth Rate.jpeg')
# Out:
# <div id="685d8244-fce9-47ab-aa44-9ac774c15bb4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("685d8244-fce9-47ab-aa44-9ac774c15bb4", [{"name": "Male", "x": ["2011", "2012", "2013", "2014", "2015", "2016", "2017"], "y": [8.95, 10.79, 3.78, -18.19, 1.99, -13.36, 20.99], "type": "bar", "uid": "2b4bacc7-d1c7-4c2a-ad77-8090ad8c2bcf"}, {"name": "Female", "x": ["2011", "2012", "2013", "2014", "2015", "2016", "2017"], "y": [6.25, 17.0, 3.71, -10.98, -2.22, -4.05, 6.65], "type": "bar", "uid": "584ca237-9235-4af6-9d67-2287863d1adb"}, {"name": "Total", "x": ["2011", "2012", "2013", "2014", "2015", "2016", "2017"], "y": [7.5, 14.09, 3.74, -14.25, -0.39, -8.18, 12.65], "type": "bar", "uid": "c49edae8-d238-4b91-a709-be789ef75d89"}], {"title": {"text": "Yearly Increase/Decrease in Birth Rate"}, "xaxis": {"title": {"text": "Year"}}, "yaxis": {"title": {"text": "Population Growth"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("685d8244-fce9-47ab-aa44-9ac774c15bb4"));});</script>

# %% [markdown]
# ### 12. Average per Month
#    Plot shows average male/female/total births and deaths per month of the year

# %%
month_wise = pd.read_csv('Insights/Month_wise_information.csv',header = 0)
a,b,c,d=[],[],[],[]
for i in range(1,13):
    if(i < 4):
        a.append(month_wise.loc[month_wise.Month == i ,'male_births'].sum() // 9)
        b.append(month_wise.loc[month_wise.Month == i ,'male_deaths'].sum() // 9)
        c.append(month_wise.loc[month_wise.Month == i ,'female_births'].sum() // 9)
        d.append(month_wise.loc[month_wise.Month == i ,'female_deaths'].sum() // 9)
    else:
        a.append(month_wise.loc[month_wise.Month == i ,'male_births'].sum() // 8)
        b.append(month_wise.loc[month_wise.Month == i ,'male_deaths'].sum() // 8)
        c.append(month_wise.loc[month_wise.Month == i ,'female_births'].sum() // 8)
        d.append(month_wise.loc[month_wise.Month == i ,'female_deaths'].sum() // 8)

monthly_avg = pd.DataFrame(columns=['Month','male_births','female_births','total_births','male_deaths','female_deaths','total_deaths'])

monthly_avg.male_births = a
monthly_avg.male_deaths = b
monthly_avg.total_births = [(x+y)/2 for x,y in zip(*[a,c])]
monthly_avg.female_births = c
monthly_avg.female_deaths = d
monthly_avg.total_deaths = [(x+y)/2 for x,y in zip(*[b,d])]

monthly_avg.Month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul','Aug', 'Sep', 'Oct', 'Nov', 'Dec']

male_birth_bar = go.Bar(x=monthly_avg.Month,y=monthly_avg.male_births,name="Male Birth")
female_birth_bar = go.Bar(x=monthly_avg.Month,y=monthly_avg.female_births,name="Female Birth")
total_birth_bar = go.Bar(x=monthly_avg.Month,y=(monthly_avg.total_births),name="Total Birth")
male_death_bar = go.Bar(x=monthly_avg.Month,y=monthly_avg.male_deaths,name="Male Death")
female_death_bar = go.Bar(x=monthly_avg.Month,y=monthly_avg.female_deaths,name="Female Death")
total_death_bar = go.Bar(x=monthly_avg.Month,y=(monthly_avg.total_deaths),name="Total Death")

data = [male_birth_bar,female_birth_bar,total_birth_bar,male_death_bar,female_death_bar,total_death_bar]

updatemenus = list([dict(type="buttons",active=-1,buttons=list([\
                        dict(label = 'Birth',method = 'update',args = [{'visible': [True,True,True,False,False,False]},{'title': 'Births'}]),\
                        dict(label = 'Death',method = 'update',args = [{'visible': [False,False,False,True,True,True]},{'title': 'Deaths'}]),\
                        dict(label = 'Male',method = 'update',args = [{'visible': [True,False,False,True,False,False]},{'title': 'Male'}]),\
                        dict(label = 'Female',method = 'update',args = [{'visible': [False,True,False,False,True,False]},{'title': 'Female'}]),\
                        dict(label = 'All',method = 'update',args = [{'visible': [True,True,True,True,True,True]},{'title': 'All'}])
                        ]),direction = 'left',xanchor = 'left',y=1.1,yanchor = 'bottom',bgcolor='white',borderwidth = 1.5)])


layout = dict(title = "Average per Month",\
             xaxis = dict(title = "Month"),\
             yaxis = dict(title = "No. of people" ),\
             updatemenus = updatemenus)

fig = dict(data = data, layout = layout)

iplot(fig)
plot(fig, filename='plots/HTML files/12. Average per Month.html')
pio.write_image(fig,'plots/Static Images/12. Average per Month.jpeg')
# Out:
# <div id="f177bebf-4be8-4ae9-aabf-f3ffe264c812" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f177bebf-4be8-4ae9-aabf-f3ffe264c812", [{"name": "Male Birth", "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2299, 2161, 2526, 2605, 2287, 2141, 2256, 2440, 2559, 2749, 2540, 2410], "type": "bar", "uid": "0827159f-585e-4abb-916d-a5fb95501f65"}, {"name": "Female Birth", "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2101, 1961, 2292, 2410, 2129, 1948, 2076, 2281, 2353, 2537, 2378, 2254], "type": "bar", "uid": "7d2a7ea9-e0ae-4919-86b1-822a4a63fa22"}, {"name": "Total Birth", "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [2200.0, 2061.0, 2409.0, 2507.5, 2208.0, 2044.5, 2166.0, 2360.5, 2456.0, 2643.0, 2459.0, 2332.0], "type": "bar", "uid": "468398d2-9569-41b8-ae04-2bfaef833ae3"}, {"name": "Male Death", "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1549, 1306, 1387, 1473, 1266, 1219, 1300, 1487, 1483, 1437, 1407, 1525], "type": "bar", "uid": "072d9006-976f-4b15-90cd-a6c1fcfd7d42"}, {"name": "Female Death", "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1084, 927, 980, 1045, 907, 828, 900, 1017, 1021, 1014, 971, 1044], "type": "bar", "uid": "56924fa2-8543-49ff-b2b7-cd852f247546"}, {"name": "Total Death", "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [1316.5, 1116.5, 1183.5, 1259.0, 1086.5, 1023.5, 1100.0, 1252.0, 1252.0, 1225.5, 1189.0, 1284.5], "type": "bar", "uid": "87dd6dad-7884-4251-bd26-2e4f2a2a3462"}], {"title": {"text": "Average per Month"}, "updatemenus": [{"active": -1, "bgcolor": "white", "borderwidth": 1.5, "buttons": [{"args": [{"visible": [true, true, true, false, false, false]}, {"title": "Births"}], "label": "Birth", "method": "update"}, {"args": [{"visible": [false, false, false, true, true, true]}, {"title": "Deaths"}], "label": "Death", "method": "update"}, {"args": [{"visible": [true, false, false, true, false, false]}, {"title": "Male"}], "label": "Male", "method": "update"}, {"args": [{"visible": [false, true, false, false, true, false]}, {"title": "Female"}], "label": "Female", "method": "update"}, {"args": [{"visible": [true, true, true, true, true, true]}, {"title": "All"}], "label": "All", "method": "update"}], "direction": "left", "type": "buttons", "xanchor": "left", "y": 1.1, "yanchor": "bottom"}], "xaxis": {"title": {"text": "Month"}}, "yaxis": {"title": {"text": "No. of people"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("f177bebf-4be8-4ae9-aabf-f3ffe264c812"));});</script>

# %% [markdown]
# ### 13. Swine-flu vs road accidents deaths
#    Plot shows percentage of swinr-flu and road accident deaths against total deaths fom year 2012 to 2017

# %%
year_wise = pd.read_csv("Insights/Year_wise_information.csv",index_col=None)
year_wise['total_deaths'] = year_wise.male_deaths + year_wise.female_deaths

ana = pd.DataFrame(columns=['Year','total_deaths','swineflu_deaths','road_accident_deaths'])
ana.Year = year_wise.Year.values[2:7]
ana.total_deaths = year_wise.total_deaths.values[2:7]
ana.swineflu_deaths = [41,46,11,153,10]
ana.road_accident_deaths = [407,399,474,543,533]
ana['swine_percent']=ana.swineflu_deaths / ana.total_deaths * 100
ana['road_percent']=ana.road_accident_deaths / ana.total_deaths * 100
display(ana)

total_trace = go.Bar(name = "Total deaths",x=ana.Year, y=ana.total_deaths,opacity = 0.8)
swine_trace = go.Bar(name = "Swine Flu deaths",x=ana.Year, y=ana.swine_percent,opacity = 0.8)
road_trace = go.Bar(name = "Road accidents deaths",x=ana.Year, y=ana.road_percent,opacity = 0.8)

data = [swine_trace,road_trace]

layout = dict(title = "Deaths Trend",\
             xaxis = dict(title = "Year"),\
             yaxis = dict(title = "Percent of total deaths" ))

fig = dict(data = data, layout = layout)

iplot(fig)
plot(fig, filename='plots/HTML files/13. Swine flu vs road accident deaths.html')
pio.write_image(fig,'plots/Static Images/13. Swine flu vs road accident deaths.jpeg')
# Out:
#    Year  total_deaths  swineflu_deaths  road_accident_deaths  swine_percent  \
# 0  2012         27322               41                   407       0.150062
# 1  2013         27473               46                   399       0.167437
# 2  2014         28244               11                   474       0.038946
# 3  2015         28569              153                   543       0.535546
# 4  2016         31374               10                   533       0.031874
#
#    road_percent
# 0      1.489642
# 1      1.452335
# 2      1.678233
# 3      1.900662
# 4      1.698859
# <div id="bff656e0-95c4-4158-83d9-a5b06eb02c66" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bff656e0-95c4-4158-83d9-a5b06eb02c66", [{"name": "Swine Flu deaths", "opacity": 0.8, "x": [2012, 2013, 2014, 2015, 2016], "y": [0.15006222092086963, 0.16743712008153458, 0.03894632488316103, 0.5355455213693164, 0.031873525849429464], "type": "bar", "uid": "c66634a4-df5a-4eec-ac58-633cc634674e"}, {"name": "Road accidents deaths", "opacity": 0.8, "x": [2012, 2013, 2014, 2015, 2016], "y": [1.4896420467022913, 1.4523350198376588, 1.6782325449653024, 1.9006615562322797, 1.6988589277745905], "type": "bar", "uid": "c51cc0a5-f722-4d07-8d27-aa0dc7a920ad"}], {"title": {"text": "Deaths Trend"}, "xaxis": {"title": {"text": "Year"}}, "yaxis": {"title": {"text": "Percent of total deaths"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("bff656e0-95c4-4158-83d9-a5b06eb02c66"));});</script>

# %% [markdown]
# ### 14. Seasonal Decompositional analysis for Birth Trend
#    Plot shows Seasonal Decomposition of Birth Trend into Trend, Seasonal and Residual

# %%
day_wise = pd.read_csv('Insights/Month_wise_information.csv',header = 0)
day_wise['DOE']= pd.to_datetime((day_wise.Year*100+day_wise.Month).apply(str),format='%Y%m')

result = seasonal_decompose(day_wise.male_births.values, model='additive', freq=5)
fig = tls.make_subplots(rows=4, cols=1, shared_xaxes=True,subplot_titles=('Total Births','Trend', 'Seasonal','Residual'))

fig.append_trace({'x': day_wise.DOE, 'y': day_wise.total_births, 'type': 'scatter', 'name': 'Total Births'}, 1, 1)
fig.append_trace({'x': day_wise.DOE, 'y': result.trend, 'type': 'scatter', 'name': 'Trend'}, 2, 1)
fig.append_trace({'x': day_wise.DOE, 'y': result.seasonal, 'type': 'scatter', 'name': 'Seasonal'}, 3, 1)
fig.append_trace({'x': day_wise.DOE, 'y': result.resid, 'type': 'scatter', 'name': 'Residual'}, 4, 1)

fig['layout'].update(height=700, width=1000, title='Sesonal Decomposition of Birth Trend',xaxis = dict(title = "Year" , rangeslider = dict(visible = True)))

iplot(fig)
plot(fig, filename='plots/HTML files/14. Seasonal Decompositional analysis for Birth Trend.html')
pio.write_image(fig, 'plots/Static Images/14. Seasonal Decompositional analysis for Birth Trend.jpeg')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
# [ (3,1) x1,y3 ]
# [ (4,1) x1,y4 ]
# <div id="4c128d94-77fe-46d9-ada4-147f145f5a98" style="height: 700px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4c128d94-77fe-46d9-ada4-147f145f5a98", [{"name": "Total Births", "x": ["2009-12-31 18:30:00", "2010-01-31 18:30:00", "2010-02-28 18:30:00", "2010-03-31 18:30:00", "2010-04-30 18:30:00", "2010-05-31 18:30:00", "2010-06-30 18:30:00", "2010-07-31 18:30:00", "2010-08-31 18:30:00", "2010-09-30 18:30:00", "2010-10-31 18:30:00", "2010-11-30 18:30:00", "2010-12-31 18:30:00", "2011-01-31 18:30:00", "2011-02-28 18:30:00", "2011-03-31 18:30:00", "2011-04-30 18:30:00", "2011-05-31 18:30:00", "2011-06-30 18:30:00", "2011-07-31 18:30:00", "2011-08-31 18:30:00", "2011-09-30 18:30:00", "2011-10-31 18:30:00", "2011-11-30 18:30:00", "2011-12-31 18:30:00", "2012-01-31 18:30:00", "2012-02-29 18:30:00", "2012-03-31 18:30:00", "2012-04-30 18:30:00", "2012-05-31 18:30:00", "2012-06-30 18:30:00", "2012-07-31 18:30:00", "2012-08-31 18:30:00", "2012-09-30 18:30:00", "2012-10-31 18:30:00", "2012-11-30 18:30:00", "2012-12-31 18:30:00", "2013-01-31 18:30:00", "2013-02-28 18:30:00", "2013-03-31 18:30:00", "2013-04-30 18:30:00", "2013-05-31 18:30:00", "2013-06-30 18:30:00", "2013-07-31 18:30:00", "2013-08-31 18:30:00", "2013-09-30 18:30:00", "2013-10-31 18:30:00", "2013-11-30 18:30:00", "2013-12-31 18:30:00", "2014-01-31 18:30:00", "2014-02-28 18:30:00", "2014-03-31 18:30:00", "2014-04-30 18:30:00", "2014-05-31 18:30:00", "2014-06-30 18:30:00", "2014-07-31 18:30:00", "2014-08-31 18:30:00", "2014
# %%
day_wise = pd.read_csv('Insights/Month_wise_information.csv',header = 0)
day_wise['DOE']= pd.to_datetime((day_wise.Year*100+day_wise.Month).apply(str),format='%Y%m')


from statsmodels.tsa.seasonal import seasonal_decompose
import plotly.tools as tls

result = seasonal_decompose(day_wise.male_deaths.values, model='additive', freq=5)
fig = tls.make_subplots(rows=4, cols=1, shared_xaxes=True,subplot_titles=('Total Births','Trend', 'Seasonal','Residual'))

fig.append_trace({'x': day_wise.DOE, 'y': day_wise.total_deaths, 'type': 'scatter', 'name': 'Total deaths'}, 1, 1)
fig.append_trace({'x': day_wise.DOE, 'y': result.trend, 'type': 'scatter', 'name': 'Trend'}, 2, 1)
fig.append_trace({'x': day_wise.DOE, 'y': result.seasonal, 'type': 'scatter', 'name': 'Seasonal'}, 3, 1)
fig.append_trace({'x': day_wise.DOE, 'y': result.resid, 'type': 'scatter', 'name': 'Residual'}, 4, 1)

fig['layout'].update(height=700, width=1000, title='Sesonal Decomposition of Death Trend',xaxis = dict(title = "Year" , rangeslider = dict(visible = True)))

iplot(fig)
plot(fig, filename='plots/HTML files/15. Seasonal Decompositional analysis for Death Trend.html')
pio.write_image(fig,'plots/Static Images/15. Seasonal Decompositional analysis for Death Trend.jpeg')
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
# [ (3,1) x1,y3 ]
# [ (4,1) x1,y4 ]
# <div id="7b68c0e9-8eb1-452f-9b5b-e634beca97d9" style="height: 700px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7b68c0e9-8eb1-452f-9b5b-e634beca97d9", [{"name": "Total deaths", "x": ["2009-12-31 18:30:00", "2010-01-31 18:30:00", "2010-02-28 18:30:00", "2010-03-31 18:30:00", "2010-04-30 18:30:00", "2010-05-31 18:30:00", "2010-06-30 18:30:00", "2010-07-31 18:30:00", "2010-08-31 18:30:00", "2010-09-30 18:30:00", "2010-10-31 18:30:00", "2010-11-30 18:30:00", "2010-12-31 18:30:00", "2011-01-31 18:30:00", "2011-02-28 18:30:00", "2011-03-31 18:30:00", "2011-04-30 18:30:00", "2011-05-31 18:30:00", "2011-06-30 18:30:00", "2011-07-31 18:30:00", "2011-08-31 18:30:00", "2011-09-30 18:30:00", "2011-10-31 18:30:00", "2011-11-30 18:30:00", "2011-12-31 18:30:00", "2012-01-31 18:30:00", "2012-02-29 18:30:00", "2012-03-31 18:30:00", "2012-04-30 18:30:00", "2012-05-31 18:30:00", "2012-06-30 18:30:00", "2012-07-31 18:30:00", "2012-08-31 18:30:00", "2012-09-30 18:30:00", "2012-10-31 18:30:00", "2012-11-30 18:30:00", "2012-12-31 18:30:00", "2013-01-31 18:30:00", "2013-02-28 18:30:00", "2013-03-31 18:30:00", "2013-04-30 18:30:00", "2013-05-31 18:30:00", "2013-06-30 18:30:00", "2013-07-31 18:30:00", "2013-08-31 18:30:00", "2013-09-30 18:30:00", "2013-10-31 18:30:00", "2013-11-30 18:30:00", "2013-12-31 18:30:00", "2014-01-31 18:30:00", "2014-02-28 18:30:00", "2014-03-31 18:30:00", "2014-04-30 